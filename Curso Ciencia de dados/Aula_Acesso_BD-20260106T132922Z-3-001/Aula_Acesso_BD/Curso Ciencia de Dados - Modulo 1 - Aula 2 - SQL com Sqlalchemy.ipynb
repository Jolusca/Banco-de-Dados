# %% [markdown]
# <h1>CURSO DATA SCIENCE</h1>
# <h2>Módulo 1: Extração de Dados</h2>
# <h3>Aula 2 - Acessando BDs Relacionais com o SqlAlchemy</h3>
# <h4>Esquema do BD Utilizado</h4>
# <p>CREATE DATABASE sefaz;<p>
#    <p>CREATE TABLE ESTABELECIMENTO ( RES_ID smallint NOT NULL, RES_NOM_ESTABELECIMENTO character varying(200), RES_ENDERECO character varying(200), RES_NUMERO character varying(200), RES_COMPLEMENTO character varying(100), RES_CEP character varying(8), RES_BAIRRO character varying(60), RES_CIDADE character varying(60), RES_UF character varying(2), RES_TELEFONE character varying(15), RES_TIP_ESTABELECIMENTO smallint NOT NULL );</p><p>CREATE TABLE TIPO_ESTABELECIMENTO ( RES_TIP_ESTABELECIMENTO smallint NOT NULL, TIPO character varying(60) ); </p>
#
# <p>INSERT INTO estabelecimento VALUES(1,'Amika Coffee House', 'Rua Ana Bilhar', '1136', 'B', '60160110', 'Meireles', 'Fortaleza', 'Ce', '(85)3031-0351',1 );</p>
# <p>INSERT INTO estabelecimento VALUES(2,'Torra Café', 'Rua Marcos Macêdo', '827', '', '60150190', 'Aldeota', 'Fortaleza', 'Ce', '',1 );</p>
# <p>INSERT INTO estabelecimento VALUES(3,'Urbici Café', 'R. Barbosa de Freitas', '951', 'Loja 01', '60170021', 'Aldeota', 'Fortaleza', 'Ce', '',2);</p>
# <p>INSERT INTO estabelecimento VALUES(4,'Blend Coffee House', 'R. Sabino Pires', '', '', '60150090', 'Aldeota', 'Fortaleza', 'Ce', '(85) 3121-6455',3);</p>
# <p>INSERT INTO tipo_estabelecimento VALUES(1, 'Comercial'); INSERT INTO tipo_estabelecimento VALUES(2, 'Privado');</p>
# <p>INSERT INTO tipo_estabelecimento VALUES(3, 'Empresarial');</p>
# <h2>Importando as Bibliotecas Necessárias</h2>

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine #Usado para conexão com BD.

# %%
# Nível zero de isolmaneto: READ UNCOMMITTED
# Para saber mais sobre nível de isolamento: https://docs.microsoft.com/pt-br/sql/connect/jdbc/understanding-isolation-levels?view=sql-server-ver15
# Níveis de isolamento do SQLAlchemy https://docs.sqlalchemy.org/en/13/dialects/postgresql.html?highlight=dialect#transaction-isolation-level
isolation_level={"isolation_level": "READ UNCOMMITTED"}

# %%
#execution_options é usado para configurar outras opções do banco
#echo é usado para mostrar o debug dos comandos SQL que o SQLAlchemy faz.
#engine = create_engine('localhost:5432/sefaz', execution_options=isolation_level, echo=False)
engine = create_engine('postgresql://postgres:123456@localhost:5432/sefaz')
conn = engine.connect()

# %%
conn

# %% [markdown]
# <h2>Manipulando PostgreSQL no DataFrame</h2>
# <h3>Executando Consultas no DataFrame</h3>

# %%
df = pd.read_sql('SELECT * FROM estabelecimento', con=conn)

# %%
df
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 0       1      Amika Coffee House         Rua Ana Bilhar       1136
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
# 3       4      Blend Coffee House        R. Sabino Pires
# 4       5              Ânimo Café       Av Pontes Vieira        417
#
#   res_complemento   res_cep          res_bairro res_cidade res_uf  \
# 0               B  60160110            Meireles  Fortaleza     Ce
# 1                  60150190             Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021             Aldeota  Fortaleza     Ce
# 3                  60150090             Aldeota  Fortaleza     Ce
# 4                  60013523  São João do Tauape  Fortaleza     Ce
#
#      res_telefone  res_tip_estabelecimento
# 0   (85)3031-0351                        1
# 1                                        1
# ...

# %%
# Imprimindo as colunas presentes no DataFrame
df.columns
# Out:
# Index(['res_id', 'res_nom_estabelecimento', 'res_endereco', 'res_numero',
#        'res_complemento', 'res_cep', 'res_bairro', 'res_cidade', 'res_uf',
#        'res_telefone', 'res_tip_estabelecimento'],
#       dtype='object')

# %%
# Checando informações gerais da tabela
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   res_id                   4 non-null      int64
#  1   res_nom_estabelecimento  4 non-null      object
#  2   res_endereco             4 non-null      object
#  3   res_numero               4 non-null      object
#  4   res_complemento          4 non-null      object
#  5   res_cep                  4 non-null      object
#  6   res_bairro               4 non-null      object
#  7   res_cidade               4 non-null      object
#  8   res_uf                   4 non-null      object
#  9   res_telefone             4 non-null      object
#  10  res_tip_estabelecimento  4 non-null      int64
# dtypes: int64(2), object(9)
# memory usage: 484.0+ bytes

# %%
# Olhando a dimensionalidade do DataFrame (linhas x colunas)
df.shape
# Out:
# (4, 11)

# %%
# Checando uma coluna específica do DataFrame
df["res_bairro"]
# Out:
# 0    Meireles
# 1     Aldeota
# 2     Aldeota
# 3     Aldeota
# Name: res_bairro, dtype: object

# %%
# Checando uma coluna específica do DataFrame com uma visualização melhor :)
df[df["res_bairro"] == "Aldeota"]
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
# 3       4      Blend Coffee House        R. Sabino Pires
#
#   res_complemento   res_cep res_bairro res_cidade res_uf    res_telefone  \
# 1                  60150190    Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021    Aldeota  Fortaleza     Ce
# 3                  60150090    Aldeota  Fortaleza     Ce  (85) 3121-6455
#
#    res_tip_estabelecimento
# 1                        1
# 2                        2
# 3                        3

# %%
# Obtendo os valores unitários de uma coluna específica
df["res_bairro"].unique()
# Out:
# array(['Meireles', 'Aldeota'], dtype=object)

# %%
# Fazendo busca por valor e retornando sua quantidade
# Usamos o index [0] para retornar apenas a quantidade de linhas em que nosso valor aparece
df[df["res_nom_estabelecimento"] == "Amika Coffee House"].shape[0]
# Out:
# 1

# %%
# checando as n primeiras instâncias do DataFrame
n = 3
df.head(n)
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 0       1      Amika Coffee House         Rua Ana Bilhar       1136
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
#
#   res_complemento   res_cep res_bairro res_cidade res_uf   res_telefone  \
# 0               B  60160110   Meireles  Fortaleza     Ce  (85)3031-0351
# 1                  60150190    Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021    Aldeota  Fortaleza     Ce
#
#    res_tip_estabelecimento
# 0                        1
# 1                        1
# 2                        2

# %%
# checando as n últimas instâncias do DataFrame
n = 2
df.tail(n)
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 2       3             Urbici Café  R. Barbosa de Freitas        951
# 3       4      Blend Coffee House        R. Sabino Pires
#
#   res_complemento   res_cep res_bairro res_cidade res_uf    res_telefone  \
# 2         Loja 01  60170021    Aldeota  Fortaleza     Ce
# 3                  60150090    Aldeota  Fortaleza     Ce  (85) 3121-6455
#
#    res_tip_estabelecimento
# 2                        2
# 3                        3

# %%
# Efetuando busca condicional
condition = (df["res_bairro"] == "Aldeota") & (df["res_numero"] != "")
df[condition]
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
#
#   res_complemento   res_cep res_bairro res_cidade res_uf res_telefone  \
# 1                  60150190    Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021    Aldeota  Fortaleza     Ce
#
#    res_tip_estabelecimento
# 1                        1
# 2                        2

# %%
# Visualizando apenas as colunas de interesse da busca anterior
columns_of_interest = ["res_nom_estabelecimento", "res_endereco", "res_numero"]
df[condition][columns_of_interest]
# Out:
#   res_nom_estabelecimento           res_endereco res_numero
# 1              Torra Café      Rua Marcos Macêdo        827
# 2             Urbici Café  R. Barbosa de Freitas        951

# %%
# Checando a dimensionalidade da consulta
# Caso deseje retornar apenas a quantidade de linhas, inserir [0] ao final de shape
df[condition][columns_of_interest].shape
# Out:
# (2, 3)

# %% [markdown]
# <h3>Funções Agregadas</h3>

# %%
# obter desvio padrão de uma coluna
np.std(df["res_id"])
# Out:
# 1.118033988749895

# %%
# obter média de uma coluna
np.mean(df["res_id"])
# Out:
# 2.5

# %%
# obter mediana de uma coluna
np.median(df["res_id"])
# Out:
# 2.5

# %%
# obter o máximo de uma coluna
np.max(df["res_id"])
# Out:
# 4

# %%
# obter o mínimo de uma coluna
np.min(df["res_id"])
# Out:
# 1

# %% [markdown]
# <h3>Junção de Tabelas</h3>

# %%
# Iremos colocar a tabela TIPO_ESTABELECIMENTO dentro do DataFrame
df2 = pd.read_sql('select * from TIPO_ESTABELECIMENTO', con=conn)

# %%
df2
# Out:
#    res_tip_estabelecimento         tipo
# 0                        1    Comercial
# 1                        2      Privado
# 2                        3  Empresarial

# %%
df2.shape
# Out:
# (3, 2)

# %%
# Faremos o JOIN das duas tabelas através da coluna "RES_TIP_ESTABELECIMENTO" e armazenaremos o resultado em um novo DF
df3 = pd.merge(df, df2, on = "res_tip_estabelecimento")

# %%
df3
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 0       1      Amika Coffee House         Rua Ana Bilhar       1136
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
# 3       4      Blend Coffee House        R. Sabino Pires
#
#   res_complemento   res_cep res_bairro res_cidade res_uf    res_telefone  \
# 0               B  60160110   Meireles  Fortaleza     Ce   (85)3031-0351
# 1                  60150190    Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021    Aldeota  Fortaleza     Ce
# 3                  60150090    Aldeota  Fortaleza     Ce  (85) 3121-6455
#
#    res_tip_estabelecimento         tipo
# 0                        1    Comercial
# 1                        1    Comercial
# 2                        2      Privado
# 3                        3  Empresarial

# %%
df3.shape
# Out:
# (4, 12)

# %% [markdown]
# <h2>Cursor</h2>

# %%
from sqlalchemy import create_engine

# %%
from sqlalchemy.sql import text
result = conn.execute(text("SELECT * FROM estabelecimento"))

# %%
rows = result.fetchall()

# %%
print(rows)
# Out:
# [(1, 'Amika Coffee House', 'Rua Ana Bilhar', '1136', 'B', '60160110', 'Meireles', 'Fortaleza', 'Ce', '(85)3031-0351', 1), (2, 'Torra Café', 'Rua Marcos Macêdo', '827', '', '60150190', 'Aldeota', 'Fortaleza', 'Ce', '', 1), (3, 'Urbici Café', 'R. Barbosa de Freitas', '951', 'Loja 01', '60170021', 'Aldeota', 'Fortaleza', 'Ce', '', 2), (4, 'Blend Coffee House', 'R. Sabino Pires', '', '', '60150090', 'Aldeota', 'Fortaleza', 'Ce', '(85) 3121-6455', 3), (5, 'Ânimo Café', 'Av Pontes Vieira', '417', '', '60013523', 'São João do Tauape', 'Fortaleza', 'Ce', '', 3)]

# %%
# Vamos inserir uma nova instância na tabela ESTABELECIMENTO
conn.execute(text("INSERT INTO estabelecimento VALUES(5,'Ânimo Café', 'Av Pontes Vieira', '417', '', '60013523', 'São João do Tauape', 'Fortaleza', 'Ce', '',3 )"))

# %%
# Verificando inserção
pd.read_sql('select * from estabelecimento', con=conn)
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 0       1      Amika Coffee House         Rua Ana Bilhar       1136
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
# 3       4      Blend Coffee House        R. Sabino Pires
# 4       5              Ânimo Café       Av Pontes Vieira        417
#
#   res_complemento   res_cep          res_bairro res_cidade res_uf  \
# 0               B  60160110            Meireles  Fortaleza     Ce
# 1                  60150190             Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021             Aldeota  Fortaleza     Ce
# 3                  60150090             Aldeota  Fortaleza     Ce
# 4                  60013523  São João do Tauape  Fortaleza     Ce
#
#      res_telefone  res_tip_estabelecimento
# 0   (85)3031-0351                        1
# 1                                        1
# ...

# %%
# Removendo instância
conn.execute(text("DELETE FROM estabelecimento WHERE RES_NOM_ESTABELECIMENTO = 'Ânimo Café'"))

# %%
# Verificando remoção
pd.read_sql('select * from estabelecimento', con=conn)
# Out:
#    res_id res_nom_estabelecimento           res_endereco res_numero  \
# 0       1      Amika Coffee House         Rua Ana Bilhar       1136
# 1       2              Torra Café      Rua Marcos Macêdo        827
# 2       3             Urbici Café  R. Barbosa de Freitas        951
# 3       4      Blend Coffee House        R. Sabino Pires
#
#   res_complemento   res_cep res_bairro res_cidade res_uf    res_telefone  \
# 0               B  60160110   Meireles  Fortaleza     Ce   (85)3031-0351
# 1                  60150190    Aldeota  Fortaleza     Ce
# 2         Loja 01  60170021    Aldeota  Fortaleza     Ce
# 3                  60150090    Aldeota  Fortaleza     Ce  (85) 3121-6455
#
#    res_tip_estabelecimento
# 0                        1
# 1                        1
# 2                        2
# 3                        3

# %% [markdown]
# <h2>Fechando a Conexão com o PostgreSQL</h2>

# %%
conn.commit()

# %%
conn.close()
